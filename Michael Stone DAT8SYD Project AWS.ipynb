# %% [markdown]
# # Data Exploration

# %%
# Input Data
import matplotlib
matplotlib.use('Agg')

import pandas as pd
zone_columns = ['Gallery King Furniture','Ground BBQ Ranch','Ground Dish Kiosk','Ground Freedom','Level 1 Dare Gallery','Level 1 JB HiFi','Level 1 Nick Scali','Level 2 Harvey Norman','Lower Ground Baby Bunting','Lower Ground Escalators']
visitors = pd.read_table('data/shoppers.txt', na_values = '\\N',names = ['shopper_date','Gallery King Furniture','Ground BBQ Ranch','Ground Dish Kiosk','Ground Freedom','Level 1 Dare Gallery','Level 1 JB HiFi','Level 1 Nick Scali','Level 2 Harvey Norman','Lower Ground Baby Bunting','Lower Ground Escalators','shopper','date','visits','day_of_week_type','arrival'])
visitors.shape
# Out:
# (285415, 16)

# %%
visitors.head()
# Out:
#         shopper_date  Gallery King Furniture  Ground BBQ Ranch  \
# 0  2017-01-02#297225                     NaN               NaN
# 1  2017-02-26#508299                     NaN               NaN
# 2  2017-03-12#545218                     NaN               NaN
# 3  2017-01-24#762703                     NaN               NaN
# 4  2017-04-22#817932                     NaN               NaN
#
#    Ground Dish Kiosk  Ground Freedom  Level 1 Dare Gallery  Level 1 JB HiFi  \
# 0               67.0             NaN                   NaN              NaN
# 1                NaN             1.0                   NaN              NaN
# 2               11.0             NaN                   NaN              NaN
# 3                NaN             NaN                   NaN              NaN
# 4                NaN             NaN                   NaN              NaN
#
#    Level 1 Nick Scali  Level 2 Harvey Norman  Lower Ground Baby Bunting  \
# 0                 NaN                    NaN                        NaN
# 1                 NaN                    NaN                        NaN
# 2                 NaN                    NaN                        NaN
# 3                 NaN                    NaN                       17.0
# 4                 NaN                    NaN                        0.0
#
#    Lower Ground Escalators  shopper        date  visits  day_of_week_type  \
# 0                      NaN   297225  2017-01-02      81                 1
# 1                      2.0   508299  2017-02-26       4                 0
# 2                      NaN   545218  2017-03-12       3                 0
# 3                      NaN   762703  2017-01-24       2                 2
# 4                      NaN   817932  2017-04-22       1                 6
#
#    arrival
# 0       11
# 1       10
# 2       14
# 3       12
# 4       13

# %%
# Convert NaN values to 0
visitors = visitors.fillna(0)

# %%
# Count number of unique shoppers
visitors.shopper.nunique()
# Out:
# 111534

# %%
# Calculate the average dwell in each column
visitors[zone_columns].mean()
# Out:
# Gallery King Furniture        5.352728
# Ground BBQ Ranch              3.453561
# Ground Dish Kiosk            20.660333
# Ground Freedom                4.479656
# Level 1 Dare Gallery          7.690552
# Level 1 JB HiFi              65.788879
# Level 1 Nick Scali            3.131356
# Level 2 Harvey Norman        34.564476
# Lower Ground Baby Bunting     4.934425
# Lower Ground Escalators       1.756498
# dtype: float64

# %% [markdown]
# Longest dwell is associated with the JB HiFi and Harvey Norman zones, both of which will have large numbers of smartphones and other WiFi enabled devices on permanent display.

# %%
# Calculate the average number of visits per shopper
print('Average visits per shopper: ',visitors[['shopper','date']].groupby(['shopper']).agg(['count']).mean())
# Out:
# Average visits per shopper:  date  count    2.558995
# dtype: float64

# %%
# Calculate min and max number of visits
print('Min ', visitors[['visits']].min())
print('Max ', visitors[['visits']].max())
# Out:
# Min  visits    1
# dtype: int64
# Max  visits    181
# dtype: int64

# %% [markdown]
# The Max visits number confirms devices are being seen every day.

# %% [markdown]
# ## Plot shoppers per day

# %%
import matplotlib.pyplot as plt
# import matplotlib
# matplotlib.use('Agg')

daily_visitors = visitors[['shopper','date']].groupby(['date']).agg(['count'])

daily_visitors_plt = daily_visitors.plot()
plt.show(daily_visitors_plt)

# %% [markdown]
# The two downward spikes are for Easter Friday and Easter Sunday when the centre was closed. Another two consecutive downward spike on 22-23 May was a backhaul connection outage.

# %% [markdown]
# ## Plot shoppers by day of week

# %%
import matplotlib.pyplot as plt

dow_visitors = visitors[['shopper','day_of_week_type']].groupby(['day_of_week_type']).agg(['count'])

dow_visitors_plt = dow_visitors.plot(kind='bar')
plt.show(dow_visitors_plt)

# %% [markdown]
# The profile shows the most popular shopping days are Saturday (6) and Sunday (0) followed by Thursday (4) when they centre is open for late night shopping.

# %% [markdown]
# ## Plot shopper visits historgram

# %%
import matplotlib.pyplot as plt

visits = visitors[['visits']]

visits_plt = visits.plot(kind='hist',bins=50)
plt.show(visits_plt)

# %% [markdown]
# Most shoppers only made one visit to the centre during the period.

# %%
# Plot shopper visits by arrival time (hour)
import matplotlib.pyplot as plt

visitors_arrivals = visitors[['shopper','arrival']].groupby(['arrival']).agg(['count'])

visitors_arrivals_plt = visitors_arrivals.plot(kind='bar')
plt.show(visitors_arrivals_plt)

# %% [markdown]
# # Proposed Clustering Techniques
#
# Potential clustering techniques to be tried include:
# - Linear SVC (sklearn.svm.LinearSVC)
# - K-Means (sklearn.cluster.KMeans)
# - DBScan (sklearn.cluster.dbscan)
#
# ## K-means

# %%
# Load libraries
from sklearn.cluster import KMeans
#import matplotlib.pyplot as plt
import numpy as np
# %matplotlib inline

# %%
# Aggregate shopper visits by total minute in each zone
visitors_agg = visitors[['shopper']+['date']+zone_columns].groupby(['shopper']).sum()

# %%
# Run K-means clustering for 11 clusters
K_count = 11
est = KMeans(n_clusters=K_count, init='random', random_state = 12345)
est.fit(visitors_agg)
# Out:
# KMeans(algorithm='auto', copy_x=True, init='random', max_iter=300,
#     n_clusters=11, n_init=10, n_jobs=1, precompute_distances='auto',
#     random_state=12345, tol=0.0001, verbose=0)

# %%
# Calculate the number of members in each cluster
unique, counts = np.unique(est.labels_, return_counts=True)

# Create a new DF with the clusters and number of members
member_count = pd.DataFrame(data=counts,
                            index=unique,
                            columns=["members"])
member_count.index.name = "label"

# Create a new DF with the clusters and their associated centres
clusters = pd.DataFrame(data=est.cluster_centers_,
                        index=unique,
                        columns=zone_columns)

# Join the member count DF to the clusters DF and round the centre numerics to 0 decimal places
member_count.join(clusters).round(0)
# Out:
#        members  Gallery King Furniture  Ground BBQ Ranch  Ground Dish Kiosk  \
# label
# 0           27                    87.0              -0.0              131.0
# 1          101                     2.0             333.0                2.0
# 2           85                     4.0              11.0               11.0
# 3           78                   788.0            1116.0            22819.0
# 4       110974                     7.0               7.0               12.0
# 5           41                     9.0             751.0            66815.0
# 6           45                     0.0             209.0                3.0
# 7          112                     7.0             441.0               20.0
# 8           15                     0.0              11.0                2.0
# 9           38                     1.0               7.0                9.0
# 10          18                 38777.0              54.0             1785.0
#
#        Ground Freedom  Level 1 Dare Gallery  Level 1 JB HiFi  \
# label
# 0                 0.0                   1.0             -0.0
# 1                 1.0                4593.0          73763.0
# 2                 1.0                   7.0              1.0
# 3               307.0                 676.0            135.0
# 4                10.0                   9.0             15.0
# 5                 0.0                 727.0              0.0
# 6                 2.0                3820.0         134408.0
# 7              1182.0                4382.0          31899.0
# 8               225.0                   0.0              3.0
# 9                 0.0                   0.0              0.0
# 10                4.0                  74.0            951.0
#
#        Level 1 Nick Scali  Level 2 Harvey Norman  Lower Ground Baby Bunting  \
# label
# 0                  2241.0               123511.0                       -0.0
# 1                   592.0                    3.0                        0.0
# 2                    18.0                24304.0                        1.0
# 3                  2207.0                  660.0                       30.0
# 4                     4.0                   17.0                        7.0
# 5                  1079.0                 1097.0                       -0.0
# 6                   794.0                    2.0                        1.0
# 7                   364.0                   12.0                        2.0
# 8                     2.0                    1.0                    38371.0
# 9                     4.0                66032.0                        0.0
# 10                  398.0                  396.0                        8.0
#
#        Lower Ground Escalators
# label
# 0                         -0.0
# 1                          0.0
# 2                          0.0
# 3                        160.0
# 4                          3.0
# 5                          0.0
# 6                          0.0
# 7                        336.0
# 8                      10148.0
# 9                          0.0
# 10                         3.0

# %%
# Calculate number of static devices or staff
member_count.sum() - member_count.iloc[4]['members']
# Out:
# members    560
# dtype: int64

# %%
# Plot the centres as a heat map
import seaborn as sns
sns.heatmap(clusters)
# Out:
# /usr/lib/python3/dist-packages/matplotlib/collections.py:549: FutureWarning: elementwise comparison failed; returning scalar instead, but in the future will perform elementwise comparison
#   if self._edgecolors == 'face':

# %% [markdown]
# #### Running a basic K-means clustering on the data with 11 clusters identifies static devices or staff who are associated with a particular zone or retailer.
#
# For example
# - Cluster 0 appears to be 27 static devices in Harvey Norman
# - Clusters 8 represent 15 static devices which can be detected in both Lower Ground Floor zones
# - Cluster 6 represents 45 static devices in JB HiFi

# %%
# Add the cluster label to our original shoppers DF
visitors_agg_clustered = visitors_agg
visitors_agg_clustered["cluster"] = est.labels_
visitors_agg_clustered
# Out:
#           Gallery King Furniture  Ground BBQ Ranch  Ground Dish Kiosk  \
# shopper
# 41                           0.0               0.0               39.0
# 1042                         0.0              25.0               20.0
# 2994                         0.0               0.0                3.0
# 5844                         0.0               0.0                0.0
# 6173                         8.0               0.0               27.0
# 7370                         0.0               3.0               16.0
# 7529                         0.0              14.0               11.0
# 7590                         0.0               0.0                0.0
# 7778                         0.0               0.0               22.0
# 9090                         0.0               0.0                0.0
# 9167                        29.0               0.0                8.0
# 9249                         0.0               5.0                0.0
# 10159                        0.0               0.0                0.0
# 10394                        0.0               0.0                0.0
# 10840                        0.0               0.0                0.0
# 10843                       20.0               3.0               44.0
# 10964                        0.0               0.0                0.0
# 11089                        0.0               0.0                3.0
# 11245                        0.0               0.0               10.0
# 11659                        0.0               0.0                0.0
# 11663                        0.0               0.0                0.0
# 11748                        0.0               0.0                0.0
# 11819                        0.0               0.0                0.0
# 12612                        0.0               0.0                0.0
# 12640                        1.0               0.0                0.0
# 12915                        0.0               0.0                0.0
# 12996                        4.0               1.0               51.0
# 13247                        0.0               0.0                0.0
# 13327                        0.0               0.0                0.0
# 13931                        0.0               0.0                2.0
# ...                          ...               ...                ...
# 21013258                     0.0               0.0                2.0
# 21013261                     0.0               0.0                1.0
# 21013286                     0.0               0.0                0.0
# 21013294                     0.0               0.0                1.0
# 21013295                     0.0               0.0                0.0
# 13327                           0.0                      0.0        4
# 13931                           0.0                      0.0        4
# ...                             ...                      ...      ...
# 21013258                        0.0                      1.0        4
# 21013261                        0.0                      0.0        4
# 21013286                        0.0                      0.0        4
# 21013294                        0.0                      0.0        4
# 21013295                        0.0                      5.0        4
# 21013358                        0.0                      0.0        4
# 21013396                        0.0                      0.0        4
# 21013428                        0.0                      0.0        4
# 21013429                        0.0                      0.0        4
# 21013430                        0.0                      0.0        4
# 21013490                        0.0                      0.0        4
# 21013491                        0.0                      0.0        4
# 21013522                        0.0                      0.0        4
# 21013534                        0.0                      0.0        4
# 21013796                        0.0                      3.0        4
# 21013819                        0.0                      0.0        4
# 21013931                        0.0                      0.0        4
# 21013946                        0.0                      0.0        4
# 21013982                        0.0                      0.0        4
# 21013992                        0.0                      1.0        4
# 21013993                        0.0                      0.0        4
# 21014022                        0.0                      0.0        4
# 21014023                        0.0                      0.0        4
# 21014055                        0.0                      0.0        4
# 21014073                        0.0                      0.0        4
# 21014083                        0.0                      0.0        4
# 21014087                        0.0                      0.0        4
# 21014131                        0.0                      0.0        4
# 21014152                        0.0                      0.0        4
# 21014177                       12.0                      1.0        4
#
# [111534 rows x 11 columns]

# %% [markdown]
# ## Run Second K-Mean Cluster on Shoppers

# %%
# Filter the shoppers for cluster #4
visitors_filtered = visitors_agg_clustered.loc[visitors_agg_clustered["cluster"] == 4][zone_columns]
visitors_filtered.shape
# Out:
# (110974, 10)

# %%
# Run K-means clustering for 11 clusters with shoppers filtered
K_count = 11
est2 = KMeans(n_clusters=K_count, init='random', random_state = 12345)
est2.fit(visitors_filtered)
# Out:
# KMeans(algorithm='auto', copy_x=True, init='random', max_iter=300,
#     n_clusters=11, n_init=10, n_jobs=1, precompute_distances='auto',
#     random_state=12345, tol=0.0001, verbose=0)

# %%
est2.cluster_centers_
# Out:
# array([[  1.13333333e+01,   3.06846667e+04,   5.99500000e+02,
#           8.22166667e+02,   5.16666667e+00,   8.38333333e+01,
#           2.16666667e+00,   9.50000000e+00,   7.66666667e+00,
#           4.69833333e+02],
#        [  1.86666667e+01,   1.33333333e+02,   1.17541667e+02,
#           9.66666667e+00,   1.45291667e+04,   2.72308333e+03,
#           5.59333333e+02,   2.42500000e+01,   9.95833333e+00,
#           3.63333333e+01],
#        [  8.73863636e+01,   5.45170455e+03,   1.83590909e+02,
#           4.01300000e+03,   1.77318182e+02,   2.78750000e+02,
#           1.11272727e+02,   9.62272727e+01,   1.06318182e+02,
#           9.03636364e+02],
#        [  4.39289706e+03,   2.23529412e+02,   4.44917647e+03,
#           1.50000000e+01,   6.01470588e+01,   9.74411765e+01,
#           3.12926471e+02,   2.76955882e+02,   2.47941176e+01,
#           1.46029412e+01],
#        [  0.00000000e+00,   0.00000000e+00,   0.00000000e+00,
#           1.10920000e+05,   0.00000000e+00,   0.00000000e+00,
#           0.00000000e+00,   0.00000000e+00,   0.00000000e+00,
#           0.00000000e+00],
#        [  2.80000000e+00,   4.14000000e+01,   2.50400000e+02,
#           2.00000000e-01,   4.81660000e+03,   1.41000000e+02,
#           2.86902000e+04,   8.23800000e+02,   1.10000000e+01,
#           2.26000000e+01],
#        [  9.63414634e+00,   9.62560976e+01,   2.50182927e+02,
#           8.44878049e+01,   7.15097561e+02,   8.68306098e+03,
#           1.39195122e+02,   1.95975610e+01,   2.41463415e+00,
#           2.90000000e+01],
#        [  1.25000000e-01,   4.16250000e+01,   7.50000000e+00,
#           1.03250000e+02,   1.62500000e+00,   1.22500000e+01,
#           2.50000000e-01,   1.37500000e+00,   1.39682500e+04,
#           6.81375000e+02],
#        [  7.04166667e+01,   2.39750000e+02,   1.49166667e+02,
#           2.25206667e+04,   1.27416667e+02,   5.06666667e+01,
#           1.49166667e+01,   9.16666667e+00,   8.55000000e+01,
#           7.41416667e+02],
#        [  2.85039370e+00,   1.67874016e+01,   2.01338583e+01,
#           3.77952756e-01,   8.13385827e+00,   1.55905512e+00,
#           5.59842520e+00,   6.52388976e+03,   9.68503937e-01,
#           1.33858268e-01],
#        [  4.15134226e+00,   2.86884816e+00,   8.99470148e+00,
#           4.94293697e+00,   4.86544843e+00,   7.95541470e+00,
#           2.49887429e+00,   8.97015290e+00,   6.42134958e+00,
#           2.14805103e+00]])

# %%
# Calculate the number of members in each cluster
unique, counts = np.unique(est2.labels_, return_counts=True)

# Create a new DF with the clusters and number of members
member_count = pd.DataFrame(data=counts,
                            index=unique,
                            columns=["members"])
member_count.index.name = "label"

# Create a new DF with the clusters and their associated centres
clusters = pd.DataFrame(data=est2.cluster_centers_,
                        index=unique,
                        columns=zone_columns)

# Join the member count DF to the clusters DF and round the centre numerics to 0 decimal places
member_count.join(clusters).round(0)
# Out:
#        members  Gallery King Furniture  Ground BBQ Ranch  Ground Dish Kiosk  \
# label
# 0            6                    11.0           30685.0              599.0
# 1           24                    19.0             133.0              118.0
# 2           44                    87.0            5452.0              184.0
# 3           68                  4393.0             224.0             4449.0
# 4            1                     0.0               0.0                0.0
# 5            5                     3.0              41.0              250.0
# 6           82                    10.0              96.0              250.0
# 7            8                     0.0              42.0                8.0
# 8           12                    70.0             240.0              149.0
# 9          127                     3.0              17.0               20.0
# 10      110597                     4.0               3.0                9.0
#
#        Ground Freedom  Level 1 Dare Gallery  Level 1 JB HiFi  \
# label
# 0               822.0                   5.0             84.0
# 1                10.0               14529.0           2723.0
# 2              4013.0                 177.0            279.0
# 3                15.0                  60.0             97.0
# 4            110920.0                   0.0              0.0
# 5                 0.0                4817.0            141.0
# 6                84.0                 715.0           8683.0
# 7               103.0                   2.0             12.0
# 8             22521.0                 127.0             51.0
# 9                 0.0                   8.0              2.0
# 10                5.0                   5.0              8.0
#
#        Level 1 Nick Scali  Level 2 Harvey Norman  Lower Ground Baby Bunting  \
# label
# 0                     2.0                   10.0                        8.0
# 1                   559.0                   24.0                       10.0
# 2                   111.0                   96.0                      106.0
# 3                   313.0                  277.0                       25.0
# 4                     0.0                    0.0                        0.0
# 5                 28690.0                  824.0                       11.0
# 6                   139.0                   20.0                        2.0
# 7                     0.0                    1.0                    13968.0
# 8                    15.0                    9.0                       85.0
# 9                     6.0                 6524.0                        1.0
# 10                    2.0                    9.0                        6.0
#
#        Lower Ground Escalators
# label
# 0                        470.0
# 1                         36.0
# 2                        904.0
# 3                         15.0
# 4                          0.0
# 5                         23.0
# 6                         29.0
# 7                        681.0
# 8                        741.0
# 9                          0.0
# 10                         2.0

# %%
# Calculate number of static devices or staff
member_count.sum() - member_count.iloc[10]['members']
# Out:
# members    377
# dtype: int64

# %%
# Plot the centres as a heat map
import seaborn as sns
sns.heatmap(clusters)
# Out:
# /usr/lib/python3/dist-packages/matplotlib/collections.py:549: FutureWarning: elementwise comparison failed; returning scalar instead, but in the future will perform elementwise comparison
#   if self._edgecolors == 'face':

# %%
visitors_filtered.shape
# Out:
# (110974, 10)

# %%
# Add the cluster label to our original shoppers DF
visitors_filtered_2 = visitors_filtered
visitors_filtered_2["cluster"] = est2.labels_
visitors_filtered_2
# Out:
#           Gallery King Furniture  Ground BBQ Ranch  Ground Dish Kiosk  \
# shopper
# 41                           0.0               0.0               39.0
# 1042                         0.0              25.0               20.0
# 2994                         0.0               0.0                3.0
# 5844                         0.0               0.0                0.0
# 6173                         8.0               0.0               27.0
# 7370                         0.0               3.0               16.0
# 7529                         0.0              14.0               11.0
# 7590                         0.0               0.0                0.0
# 7778                         0.0               0.0               22.0
# 9090                         0.0               0.0                0.0
# 9167                        29.0               0.0                8.0
# 9249                         0.0               5.0                0.0
# 10159                        0.0               0.0                0.0
# 10394                        0.0               0.0                0.0
# 10840                        0.0               0.0                0.0
# 10843                       20.0               3.0               44.0
# 10964                        0.0               0.0                0.0
# 11089                        0.0               0.0                3.0
# 11245                        0.0               0.0               10.0
# 11659                        0.0               0.0                0.0
# 11663                        0.0               0.0                0.0
# 11748                        0.0               0.0                0.0
# 11819                        0.0               0.0                0.0
# 12612                        0.0               0.0                0.0
# 12640                        1.0               0.0                0.0
# 12915                        0.0               0.0                0.0
# 12996                        4.0               1.0               51.0
# 13247                        0.0               0.0                0.0
# 13327                        0.0               0.0                0.0
# 13931                        0.0               0.0                2.0
# ...                          ...               ...                ...
# 21013258                     0.0               0.0                2.0
# 21013261                     0.0               0.0                1.0
# 21013286                     0.0               0.0                0.0
# 21013294                     0.0               0.0                1.0
# 21013295                     0.0               0.0                0.0
# 21013358                     0.0               0.0                2.0
# 21013396                     0.0               0.0                0.0
# 21013428                     0.0               0.0                0.0
# 21013429                     0.0               0.0                1.0
# 21013430                     0.0               0.0                0.0
# 21013490                     0.0               0.0                0.0
# 21013491                     0.0               0.0                6.0
# 21013522                     0.0               0.0                0.0
# 21013534                     0.0               0.0                1.0
# 21013796                     0.0               0.0                0.0
# 21013819                     0.0               0.0                0.0
# 21013931                     0.0               0.0                1.0
# 21013946                     0.0               0.0                0.0
# 21013982                     0.0               0.0                0.0
# 21013992                     0.0               0.0                0.0
# 21013993                     0.0               0.0                0.0
# 21014022                     0.0               0.0                0.0
# 21014023                     0.0               0.0                0.0
# 21014055                     0.0               0.0                0.0
# 21014073                     0.0               0.0                0.0
# 21014083                     0.0               0.0                0.0
# 21014087                     0.0               0.0                0.0
# 21014131                     0.0               0.0                0.0
# 21014152                     0.0               0.0                0.0
# 21014177                     0.0               0.0                0.0
#
#           Ground Freedom  Level 1 Dare Gallery  Level 1 JB HiFi  \
# shopper
# 41                   0.0                   0.0              0.0
# 1042                 7.0                   2.0             33.0
# 2994                 0.0                   0.0              0.0
# 5844                 0.0                   2.0             12.0
# 6173                34.0                  45.0              8.0
# 7370                19.0                   0.0             21.0
# 7529                10.0                   0.0             10.0
# 7590                 0.0                   0.0              0.0
# 7778                 0.0                   0.0              0.0
# 9090                 0.0                  20.0              3.0
# 9167                 0.0                   2.0             30.0
# 9249                 1.0                   0.0              0.0
# 21013490                 0.0                   10.0
# 21013491                 0.0                   10.0
# 21013522                 0.0                    0.0
# 21013534                 0.0                    2.0
# 21013796                 0.0                    0.0
# 21013819                 0.0                    1.0
# 21013931                 0.0                   26.0
# 21013946                 0.0                    4.0
# 21013982                 0.0                    0.0
# 21013992                 0.0                    0.0
# 21013993                 0.0                   12.0
# 21014022                 0.0                   16.0
# 21014023                 0.0                    1.0
# 21014055                 0.0                    0.0
# 21014073                 0.0                    6.0
# 21014083                 0.0                   40.0
# 21014087                 0.0                    6.0
# 21014131                 0.0                    0.0
# 21014152                 0.0                   17.0
# 21014177                 0.0                    0.0
#
#           Lower Ground Baby Bunting  Lower Ground Escalators  cluster
# shopper
# 41                              0.0                      0.0       10
# 1042                            2.0                      2.0       10
# 2994                            0.0                      0.0       10
# 5844                            0.0                      0.0       10
# 6173                            2.0                      0.0       10
# 7370                            0.0                      2.0       10
# 7529                            4.0                      4.0       10
# 7590                            0.0                      0.0       10
# 7778                            0.0                      0.0       10
# 9090                           46.0                      0.0       10
# 9167                            0.0                      0.0       10
# 9249                            0.0                      2.0       10
# 10159                           0.0                      0.0       10
# 10394                           0.0                      0.0       10
# 10840                           0.0                      0.0       10
# 10843                           3.0                      0.0       10
# 10964                           0.0                      0.0       10
# 11089                           0.0                      0.0       10
# 11245                           0.0                      2.0       10
# 11659                          19.0                      0.0       10
# 11663                           0.0                      0.0       10
# 11748                           0.0                      0.0       10
# 11819                           0.0                      0.0       10
# 12612                           0.0                      0.0       10
# 12640                           0.0                      0.0       10
# 12915                           0.0                      1.0       10
# 12996                           0.0                      0.0       10
# 13247                          36.0                      0.0       10
# 13327                           0.0                      0.0       10
# 13931                           0.0                      0.0       10
# ...                             ...                      ...      ...
# 21013258                        0.0                      1.0       10
# 21013261                        0.0                      0.0       10
# 21013286                        0.0                      0.0       10
# 21013294                        0.0                      0.0       10
# 21013295                        0.0                      5.0       10
# 21013358                        0.0                      0.0       10
# 21013396                        0.0                      0.0       10
# 21013428                        0.0                      0.0       10
# 21013429                        0.0                      0.0       10
# 21013430                        0.0                      0.0       10
# 21013490                        0.0                      0.0       10
# 21013491                        0.0                      0.0       10
# 21013522                        0.0                      0.0       10
# 21013534                        0.0                      0.0       10
# 21013796                        0.0                      3.0       10
# 21013819                        0.0                      0.0       10
# 21013931                        0.0                      0.0       10
# 21013946                        0.0                      0.0       10
# 21013982                        0.0                      0.0       10
# 21013992                        0.0                      1.0       10
# 21013993                        0.0                      0.0       10
# 21014022                        0.0                      0.0       10
# 21014023                        0.0                      0.0       10
# 21014055                        0.0                      0.0       10
# 21014073                        0.0                      0.0       10
# 21014083                        0.0                      0.0       10
# 21014087                        0.0                      0.0       10
# 21014131                        0.0                      0.0       10
# 21014152                        0.0                      0.0       10
# 21014177                       12.0                      1.0       10
#
# [110974 rows x 11 columns]

# %%
## Try a 3rd K-Mean on filtered shoppers

# %%
# Separate our cluster #10 as real shoppers
visitors_filtered_3 = visitors_filtered_2.loc[visitors_filtered_2["cluster"] == 10][zone_columns]
visitors_filtered_3.shape
# Out:
# (110597, 10)

# %%
# Run K-means clustering for 11 clusters with shoppers filtered
K_count = 11
est3 = KMeans(n_clusters=K_count, init='random', random_state = 12345)
est3.fit(visitors_filtered_3)
# Out:
# KMeans(algorithm='auto', copy_x=True, init='random', max_iter=300,
#     n_clusters=11, n_init=10, n_jobs=1, precompute_distances='auto',
#     random_state=12345, tol=0.0001, verbose=0)

# %%
est3.cluster_centers_
# Out:
# array([[  6.01190476e+00,   3.14166667e+01,   1.80476190e+01,
#           2.26190476e-01,   2.20488095e+02,   2.63648810e+03,
#           1.44285714e+01,   2.70238095e+00,   1.52976190e+01,
#           1.50476190e+01],
#        [  2.50051852e+03,   1.62962963e+01,   1.35037037e+02,
#           6.29629630e-01,   9.14814815e+00,   1.74074074e+00,
#           3.63703704e+01,   3.40000000e+01,   1.18518519e+00,
#           1.40740741e+00],
#        [  3.89692308e+02,   1.85384615e+01,   7.51538462e+01,
#           4.61538462e-01,   1.98923077e+02,   4.91538462e+01,
#           6.44569231e+03,   2.02000000e+02,   2.76923077e+00,
#           4.00000000e+00],
#        [  3.32739726e+01,   5.91232877e+01,   2.43795890e+03,
#           7.00000000e+00,   5.34383562e+01,   5.40821918e+01,
#           5.57808219e+01,   6.34794521e+01,   6.16438356e+00,
#           8.76712329e+00],
#        [  3.32321045e+00,   2.12225115e+00,   6.31436663e+00,
#           4.22665022e+00,   3.25789594e+00,   4.79481979e+00,
#           1.34264310e+00,   5.38497099e+00,   5.52465397e+00,
#           2.00226577e+00],
#        [  6.89655172e-01,   7.07241379e+01,   1.04827586e+01,
#           5.89655172e+00,   8.10344828e+00,   1.18965517e+01,
#           6.89655172e-02,   3.24137931e+00,   3.22586207e+03,
#           2.00034483e+02],
#        [  2.46030641e+01,   1.74164345e+01,   1.51123955e+02,
#           1.25640669e+01,   1.27193593e+02,   1.54537604e+02,
#           4.86448468e+01,   2.01527855e+02,   1.27924791e+01,
#           6.29247911e+00],
#        [  6.59375000e+00,   1.50531250e+02,   2.17812500e+01,
#           2.14150000e+03,   2.31250000e+01,   1.93750000e+01,
#           1.87500000e-01,   1.78125000e+00,   2.31875000e+01,
#           1.05343750e+02],
#        [  1.45384615e+01,   2.15730769e+03,   1.14653846e+02,
#           1.82692308e+02,   5.83846154e+01,   5.83846154e+01,
#           6.94230769e+01,   5.46923077e+01,   3.00000000e+00,
#           9.70000000e+01],
#        [  1.32500000e+01,   3.25833333e+01,   2.48250000e+02,
#           6.73333333e+01,   5.02316667e+03,   1.01583333e+03,
#           1.56916667e+02,   1.34166667e+02,   2.83333333e+00,
#           1.33333333e+01],
#        [  1.12265625e+01,   1.17578125e+01,   3.17968750e+01,
#           1.67968750e+00,   1.68750000e+01,   2.57656250e+01,
#           5.67187500e+00,   1.92480469e+03,   6.95312500e-01,
#           3.43750000e-01]])

# %%
# Calculate the number of members in each cluster
unique, counts = np.unique(est3.labels_, return_counts=True)

# Create a new DF with the clusters and number of members
member_count = pd.DataFrame(data=counts,
                            index=unique,
                            columns=["members"])
member_count.index.name = "label"

# Create a new DF with the clusters and their associated centres
clusters = pd.DataFrame(data=est3.cluster_centers_,
                        index=unique,
                        columns=zone_columns)

# Join the member count DF to the clusters DF and round the centre numerics to 0 decimal places
member_count.join(clusters).round(0)
# Out:
#        members  Gallery King Furniture  Ground BBQ Ranch  Ground Dish Kiosk  \
# label
# 0           84                     6.0              31.0               18.0
# 1           27                  2501.0              16.0              135.0
# 2           13                   390.0              19.0               75.0
# 3           73                    33.0              59.0             2438.0
# 4       109455                     3.0               2.0                6.0
# 5           29                     1.0              71.0               10.0
# 6          718                    25.0              17.0              151.0
# 7           32                     7.0             151.0               22.0
# 8           26                    15.0            2157.0              115.0
# 9           12                    13.0              33.0              248.0
# 10         128                    11.0              12.0               32.0
#
#        Ground Freedom  Level 1 Dare Gallery  Level 1 JB HiFi  \
# label
# 0                 0.0                 220.0           2636.0
# 1                 1.0                   9.0              2.0
# 2                 0.0                 199.0             49.0
# 3                 7.0                  53.0             54.0
# 4                 4.0                   3.0              5.0
# 5                 6.0                   8.0             12.0
# 6                13.0                 127.0            155.0
# 7              2142.0                  23.0             19.0
# 8               183.0                  58.0             58.0
# 9                67.0                5023.0           1016.0
# 10                2.0                  17.0             26.0
#
#        Level 1 Nick Scali  Level 2 Harvey Norman  Lower Ground Baby Bunting  \
# label
# 0                    14.0                    3.0                       15.0
# 1                    36.0                   34.0                        1.0
# 2                  6446.0                  202.0                        3.0
# 3                    56.0                   63.0                        6.0
# 4                     1.0                    5.0                        6.0
# 5                     0.0                    3.0                     3226.0
# 6                    49.0                  202.0                       13.0
# 7                     0.0                    2.0                       23.0
# 8                    69.0                   55.0                        3.0
# 9                   157.0                  134.0                        3.0
# 10                    6.0                 1925.0                        1.0
#
#        Lower Ground Escalators
# label
# 0                         15.0
# 1                          1.0
# 2                          4.0
# 3                          9.0
# 4                          2.0
# 5                        200.0
# 6                          6.0
# 7                        105.0
# 8                         97.0
# 9                         13.0
# 10                         0.0

# %%
# Calculate number of static devices or staff
member_count.sum() - member_count.iloc[4]['members']
# Out:
# members    1142
# dtype: int64

# %%
# Plot the centres as a heat map
import seaborn as sns
sns.heatmap(clusters)
# Out:
# /usr/lib/python3/dist-packages/matplotlib/collections.py:549: FutureWarning: elementwise comparison failed; returning scalar instead, but in the future will perform elementwise comparison
#   if self._edgecolors == 'face':

# %% [markdown]
# # Remove staff and static devices based on number of visits
# Going to be very slow to converge so need to do this manually before the K-mean clustering

# %%
# Calculate total visit during based on summing dwells
visitors_total = visitors
visitors_total['duration'] = visitors_total[zone_columns].sum(axis=1) 

# Calculate the number of visited zones during visit 
visitors_total['zone_count'] = (visitors_total[zone_columns] > 0).astype(int).sum(axis=1)

# Check if any zone dwells are more than 120 mins
visitors_total['long_dwell'] = (visitors_total[zone_columns]>120).any(axis=1)


# Assume shoppers will have the following characteristics
# - Less than 20 visits
# - Less than 120 minutes in any one zone
# - Between than 30 minutes and 240 minutes total duration
# - More than 1 active zone 
shoppers = visitors.query('visits <= 20 & duration > 30 & duration < 240 and zone_count > 1 and not(long_dwell)')
shoppers.shape
# Out:
# (38782, 19)

# %%
## Run K-Mean on shoppers

# %%
# Run K-means clustering for 11 clusters
K_count = 10
est = KMeans(n_clusters=K_count, init='random', random_state = 12345)
est.fit(shoppers[zone_columns])
# Out:
# KMeans(algorithm='auto', copy_x=True, init='random', max_iter=300,
#     n_clusters=10, n_init=10, n_jobs=1, precompute_distances='auto',
#     random_state=12345, tol=0.0001, verbose=0)

# %%
# Calculate the number of members in each cluster
unique, counts = np.unique(est.labels_, return_counts=True)

# Create a new DF with the clusters and number of members
member_count = pd.DataFrame(data=counts,
                            index=unique,
                            columns=["members"])
member_count.index.name = "label"

# Create a new DF with the clusters and their associated centres
clusters = pd.DataFrame(data=est.cluster_centers_,
                        index=unique,
                        columns=zone_columns)

# Join the member count DF to the clusters DF and round the centre numerics to 0 decimal places
member_count.join(clusters).round(0)
# Out:
#        members  Gallery King Furniture  Ground BBQ Ranch  Ground Dish Kiosk  \
# label
# 0         3876                     2.0               1.0                5.0
# 1          758                     0.0               1.0                1.0
# 2         3887                     4.0               3.0               41.0
# 3         3888                     3.0               4.0                7.0
# 4         1291                     3.0               2.0                6.0
# 5         3430                     3.0               1.0                4.0
# 6         2638                    42.0               2.0                7.0
# 7         9640                     4.0               6.0                8.0
# 8         3993                     1.0               1.0                4.0
# 9         5381                     2.0               2.0                6.0
#
#        Ground Freedom  Level 1 Dare Gallery  Level 1 JB HiFi  \
# label
# 0                 2.0                   2.0              2.0
# 1                 1.0                   1.0              1.0
# 2                 5.0                   2.0              3.0
# 3                39.0                   3.0              3.0
# 4                 3.0                   4.0              5.0
# 5                 3.0                  40.0              6.0
# 6                 4.0                   3.0              3.0
# 7                 6.0                   4.0              5.0
# 8                 2.0                   5.0             39.0
# 9                 3.0                   2.0              5.0
#
#        Level 1 Nick Scali  Level 2 Harvey Norman  Lower Ground Baby Bunting  \
# label
# 0                     1.0                    1.0                       40.0
# 1                     0.0                    0.0                        8.0
# 2                     2.0                    3.0                        2.0
# 3                     2.0                    3.0                        1.0
# 4                     2.0                   67.0                        1.0
# 5                     2.0                    3.0                        2.0
# 6                     3.0                    3.0                        2.0
# 7                     5.0                    3.0                        3.0
# 8                     1.0                    4.0                        1.0
# 9                     2.0                   27.0                        1.0
#
#        Lower Ground Escalators
# label
# 0                          3.0
# 1                         44.0
# 2                          1.0
# 3                          1.0
# 4                          1.0
# 5                          1.0
# 6                          1.0
# 7                          1.0
# 8                          1.0
# 9                          1.0

# %%
# Plot the centres as a heat map
import seaborn as sns
sns.heatmap(clusters)
# Out:
# /usr/lib/python3/dist-packages/matplotlib/collections.py:549: FutureWarning: elementwise comparison failed; returning scalar instead, but in the future will perform elementwise comparison
#   if self._edgecolors == 'face':

# %% [markdown]
# Using 10 clusters results in clusters focused on dwelling in each individual zone except for BBQ ranch

# %%
# Create a bunch of different models
k_rng = range(1,25)
d= shoppers[zone_columns]
est = [KMeans(n_clusters = k).fit(d) for k in k_rng]

#================================
# Option 1: Silhouette Coefficient
# Generally want SC to be closer to 1, while also minimizing k

from sklearn import metrics
silhouette_scores = [metrics.silhouette_score(d, e.labels_, metric='euclidean') for e in est[1:]]

silhouette_scores

# Plot the results
plt.figure(figsize=(7, 8))
plt.subplot(211)
plt.title('Using the elbow method to inform k choice')
plt.plot(k_rng[1:], silhouette_scores, 'b*-')
plt.xlim([1,15])
plt.grid(True)
plt.ylabel('Silhouette Coefficient')
plt.plot(3,silhouette_scores[1], 'o', markersize=12, markeredgewidth=1.5,
         markerfacecolor='None', markeredgecolor='r')

# %% [markdown]
# Need to use a bigger computer!

# %% [raw]
# gcloud dataproc clusters create datascience --initialization-actions gs://dataproc-initialization-actions/jupyter/jupyter.sh
# gcloud compute ssh  --zone=australia-southeast1-a --ssh-flag="-D 1080" --ssh-flag="-N" --ssh-flag="-n" datascience-m:8123
